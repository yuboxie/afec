# %%
import os
import pickle
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity

# %%
all_posts_df = pd.read_csv('../data/merged_q/all_posts_max_len_40.csv')
all_replies_df = pd.read_csv('../data/merged_q/all_replies_max_len_40.csv')
print('all_posts_df shape = {}'.format(all_posts_df.shape))
print('all_replies_df shape = {}'.format(all_replies_df.shape))
# Out:
# all_posts_df shape = (152680, 5)
# all_replies_df shape = (838785, 5)

# %%
all_posts_embed = np.load('../data/merged_q/all_posts_max_len_40_embed.npy')
all_replies_embed = np.load('../data/merged_q/all_replies_max_len_40_embed.npy')
print('all_posts_embed shape = {}'.format(all_posts_embed.shape))
print('all_replies_embed shape = {}'.format(all_replies_embed.shape))
# Out:
# all_posts_embed shape = (152680, 768)
# all_replies_embed shape = (838785, 768)

# %% [markdown]
# ## Select out ED Testing Data

# %%
all_posts_df
# Out:
#                                  id  summarized  \
# 0                            r2wyka           0
# 1                            r2wc2q           0
# 2                            r2w43k           0
# 3                            r2vbm3           0
# 4                            r2v7x0           0
# ...                             ...         ...
# 152675  hit:12318_conv:24637_uttr:1           0
# 152676  hit:12384_conv:24768_uttr:1           0
# 152677  hit:12390_conv:24781_uttr:1           0
# 152678  hit:12398_conv:24797_uttr:1           1
# 152679  hit:12416_conv:24832_uttr:1           0
#
#                                                      text     root  length
# 0                        Can you learn to be less afraid?    learn       8
# 1       Why doesn't Activia use the word "yogurt" on t...      use      14
# 2       Do you ever feel like everyone else has it tog...     feel      13
# 3       Does pressing keyboard keys reflect your perso...  reflect       8
# 4       My boss told me that during the time my hair w...     make      21
# ...                                                   ...      ...     ...
# 152675  I don't like scammy sales people, nothing good...     come      13
# 152676    I almost got caught stealing, I felt pretty bad     feel      10
# 152677  Some random dude walked into my room while I w...     walk      19
# 152678       I saw my favourite candy at the store today!      see      10
# 152679     I saw a huge cockroach outside my house today!      see      10
#
# [152680 rows x 5 columns]

# %%
ed_test_df = pd.read_csv('../data/ed/raw/test.csv')
ed_test_df
# Out:
#                     conv_id  utterance_idx    context  \
# 0              hit:0_conv:0              1     guilty
# 1              hit:0_conv:0              2     guilty
# 2              hit:0_conv:0              3     guilty
# 3              hit:0_conv:0              4     guilty
# 4              hit:0_conv:0              5     guilty
# ...                     ...            ...        ...
# 10864  hit:12416_conv:24832              4  disgusted
# 10865  hit:12423_conv:24847              1    anxious
# 10866  hit:12423_conv:24847              2    anxious
# 10867  hit:12423_conv:24847              3    anxious
# 10868  hit:12423_conv:24847              4    anxious
#
#                                                   prompt  speaker_idx  \
# 0      I felt guilty when I was driving home one nigh...            0
# 1      I felt guilty when I was driving home one nigh...            1
# 2      I felt guilty when I was driving home one nigh...            0
# 3      I felt guilty when I was driving home one nigh...            1
# 4      I felt guilty when I was driving home one nigh...            0
# ...                                                  ...          ...
# 10864  I saw a huge cockroach outside my house today....           46
# 10865  I have a big test on Monday. I am so nervous_c...          481
# 10866  I have a big test on Monday. I am so nervous_c...          375
# 10867  I have a big test on Monday. I am so nervous_c...          481
# 10868  I have a big test on Monday. I am so nervous_c...          375
#
#                                                utterance     selfeval tags
# 0      Yeah about 10 years ago I had a horrifying exp...  2|2|5_5|5|5  NaN
# 1                           Did you suffer any injuries?  2|2|5_5|5|5  NaN
# 2      No I wasn't hit. It turned out they were drunk...  2|2|5_5|5|5  NaN
# 3      Why did you feel guilty? People really shouldn...  2|2|5_5|5|5  NaN
# 4      I don't know I was new to driving and hadn't e...  2|2|5_5|5|5  NaN
# ...                                                  ...          ...  ...
# 10864           I live in Texas to so i know those feels  5|5|5_4|3|4  NaN
# 10865  I have a big test on Monday_comma_ I am so ner...  5|5|5_5|5|5  NaN
# 10866                               What is the test on?  5|5|5_5|5|5  NaN
# 10867  It's for my Chemistry class. I haven't slept m...  5|5|5_5|5|5  NaN
# 10868  Chemistry is quite difficult_comma_have you st...  5|5|5_5|5|5  NaN
#
# [10869 rows x 8 columns]

# %%
ed_test_ids = [x + '_uttr:1' for x in ed_test_df['conv_id'].tolist()]
ed_test_posts_df = all_posts_df[all_posts_df['id'].isin(ed_test_ids)]
ed_test_posts_df
# Out:
#                                  id  summarized  \
# 151405        hit:40_conv:81_uttr:1           0
# 151406      hit:104_conv:208_uttr:1           0
# 151407      hit:136_conv:273_uttr:1           1
# 151408      hit:142_conv:285_uttr:1           1
# 151409      hit:143_conv:286_uttr:1           1
# ...                             ...         ...
# 152675  hit:12318_conv:24637_uttr:1           0
# 152676  hit:12384_conv:24768_uttr:1           0
# 152677  hit:12390_conv:24781_uttr:1           0
# 152678  hit:12398_conv:24797_uttr:1           1
# 152679  hit:12416_conv:24832_uttr:1           0
#
#                                                      text   root  length
# 151405              I couldn't wait to go to the concert.   wait      10
# 151406  i just moved to this neighborhood and some dum...   move      21
# 151407        So yeah i drove 2 hours to get to wallmart.  drive      11
# 151408  My friend's boyfriend recently made a pass at me.   make      11
# 151409                               my baby is sleeping.  sleep       5
# ...                                                   ...    ...     ...
# 152675  I don't like scammy sales people, nothing good...   come      13
# 152676    I almost got caught stealing, I felt pretty bad   feel      10
# 152677  Some random dude walked into my room while I w...   walk      19
# 152678       I saw my favourite candy at the store today!    see      10
# 152679     I saw a huge cockroach outside my house today!    see      10
#
# [1275 rows x 5 columns]

# %%
ed_test_posts_ids = ed_test_posts_df['id'].tolist()
print(ed_test_posts_ids[:10])
print('len(ed_test_posts_ids) = {}'.format(len(ed_test_posts_ids)))
# Out:
# ['hit:40_conv:81_uttr:1', 'hit:104_conv:208_uttr:1', 'hit:136_conv:273_uttr:1', 'hit:142_conv:285_uttr:1', 'hit:143_conv:286_uttr:1', 'hit:147_conv:294_uttr:1', 'hit:171_conv:342_uttr:1', 'hit:173_conv:346_uttr:1', 'hit:175_conv:351_uttr:1', 'hit:207_conv:414_uttr:1']
# len(ed_test_posts_ids) = 1275

# %% [markdown]
# ## Select out 10% of Reddit

# %%
all_reddit_posts_df = all_posts_df[~all_posts_df['id'].str.startswith('hit:')]
all_reddit_posts_df
# Out:
#             id  summarized                                               text  \
# 0       r2wyka           0                   Can you learn to be less afraid?
# 1       r2wc2q           0  Why doesn't Activia use the word "yogurt" on t...
# 2       r2w43k           0  Do you ever feel like everyone else has it tog...
# 3       r2vbm3           0  Does pressing keyboard keys reflect your perso...
# 4       r2v7x0           0  My boss told me that during the time my hair w...
# ...        ...         ...                                                ...
# 139373  50mj2d           0                   I kind of hate today's rap music
# 139374  4ze20k           1  I can't watch shows like "The Office" because ...
# 139375  4ypvyx           1  For me, I usually get a small thing of regular...
# 139376  4vkgnz           0                              Tell me what to draw!
# 139377  4sfco1           0  Do you ever ask yourself "Will I ever find tru...
#
#            root  length
# 0         learn       8
# 1           use      14
# 2          feel      13
# 3       reflect       8
# 4          make      21
# ...         ...     ...
# 139373     hate       8
# 139374    watch      19
# 139375      get      33
# 139376     tell       6
# 139377      ask      14
#
# [139378 rows x 5 columns]

# %%
N = all_reddit_posts_df.shape[0]
N_test = N // 10
test_indices = np.random.choice(N, N_test, replace = False)
print('len(test_indices) = {}'.format(len(test_indices)))
# Out:
# len(test_indices) = 13937

# %%
reddit_test_posts_df = all_reddit_posts_df.iloc[test_indices]
reddit_test_posts_df
# Out:
#             id  summarized                                               text  \
# 76609   aq3i5j           1  I was just told that I apparently give really ...
# 22839   igtkhr           0  Does anyone want to argue about nonsense for fun?
# 47602   evisbc           1  Just wanted to see if anyone would wanna play ...
# 116385  7d547p           0                 How do you overcome stage fright ?
# 115195  7g2yvn           0                             cracking phone screens
# ...        ...         ...                                                ...
# 139248  5ln2kk           0  Today I was told by a boy in my class that my ...
# 95651   8wxlqx           0                   I got kicked out of a club today
# 122856  6zv1bf           0                         Gaming pc recommendations?
# 58973   d65640           0       I just missed an opportunity to kiss a girl.
# 3811    pbjhw1           0  I'm thinking about taking a gap year to reduce...
#
#             root  length
# 76609       tell      13
# 22839       want      10
# 47602       want      17
# 116385  overcome       7
# 115195     crack       3
# ...          ...     ...
# 139248      tell      39
# 95651       kick       8
# 122856      game       4
# 58973       miss      10
# 3811       think      12
#
# [13937 rows x 5 columns]

# %%
reddit_test_posts_ids = reddit_test_posts_df['id'].tolist()
print(reddit_test_posts_ids[:10])
print('len(reddit_test_posts_ids) = {}'.format(len(reddit_test_posts_ids)))
# Out:
# ['aq3i5j', 'igtkhr', 'evisbc', '7d547p', '7g2yvn', 'outioh', '6vl72e', 'a7sg8w', 'a4kskn', 'cnmomt']
# len(reddit_test_posts_ids) = 13937

# %% [markdown]
# ## Combine

# %%
rows = test_indices.tolist() + list(range(151405, 152680))
print('total number of testing points: {}'.format(len(rows)))
# Out:
# total number of testing points: 15212

# %%
np.save('../data/test/posts_indices.npy', np.array(rows))

# %% [markdown]
# ## Create Test DF

# %%
test_posts_df = all_posts_df.iloc[rows]
test_posts_df
# Out:
#                                  id  summarized  \
# 76609                        aq3i5j           1
# 22839                        igtkhr           0
# 47602                        evisbc           1
# 116385                       7d547p           0
# 115195                       7g2yvn           0
# ...                             ...         ...
# 152675  hit:12318_conv:24637_uttr:1           0
# 152676  hit:12384_conv:24768_uttr:1           0
# 152677  hit:12390_conv:24781_uttr:1           0
# 152678  hit:12398_conv:24797_uttr:1           1
# 152679  hit:12416_conv:24832_uttr:1           0
#
#                                                      text      root  length
# 76609   I was just told that I apparently give really ...      tell      13
# 22839   Does anyone want to argue about nonsense for fun?      want      10
# 47602   Just wanted to see if anyone would wanna play ...      want      17
# 116385                 How do you overcome stage fright ?  overcome       7
# 115195                             cracking phone screens     crack       3
# ...                                                   ...       ...     ...
# 152675  I don't like scammy sales people, nothing good...      come      13
# 152676    I almost got caught stealing, I felt pretty bad      feel      10
# 152677  Some random dude walked into my room while I w...      walk      19
# 152678       I saw my favourite candy at the store today!       see      10
# 152679     I saw a huge cockroach outside my house today!       see      10
#
# [15212 rows x 5 columns]

# %%
test_posts_df.to_csv('../data/test/posts.csv', index = False)

# %%
test_replies_df = pd.DataFrame()

# %%
for post_id in tqdm(test_posts_df['id'].tolist()):
    df = all_replies_df[all_replies_df['parent_id'] == post_id]
    assert df.shape[0] > 0
    test_replies_df = pd.concat([test_replies_df, df])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15212/15212 [09:32<00:00, 26.57it/s]

# %%
test_replies_df
# Out:
#                                  id                    parent_id  summarized  \
# 439033                      egd6ti7                       aq3i5j           1
# 439034                      egd78yr                       aq3i5j           1
# 439043                      egda9u6                       aq3i5j           1
# 439098                      ege6pa6                       aq3i5j           1
# 141011                      g2vwz9z                       igtkhr           1
# ...                             ...                          ...         ...
# 838780  hit:12318_conv:24637_uttr:2  hit:12318_conv:24637_uttr:1           0
# 838781  hit:12384_conv:24768_uttr:2  hit:12384_conv:24768_uttr:1           1
# 838782  hit:12390_conv:24781_uttr:2  hit:12390_conv:24781_uttr:1           1
# 838783  hit:12398_conv:24797_uttr:2  hit:12398_conv:24797_uttr:1           1
# 838784  hit:12416_conv:24832_uttr:2  hit:12416_conv:24832_uttr:1           0
#
#                                                 text  length
# 439033                                       Thanks.       2
# 439034                    Boundaries advice i guess?       5
# 439043                      Practically never start.       4
# 439098                     How to not feel inferior?       6
# 141011  Why not paint them white or a bright yellow?      10
# ...                                              ...     ...
# 838780    I agree, were you recently screwed by one?      10
# 838781                                         Ouch!       2
# 838782                         Oh wow that is weird.       6
# 838783                                      Oh nice.       3
# 838784                did you call the exterminator?       6
#
# [82284 rows x 5 columns]

# %%
test_replies_df.to_csv('../data/test/replies.csv', index = False)

# %%
all_replies_ids = all_replies_df['id'].tolist()
test_replies_ids = []
for reply_id in tqdm(test_replies_df['id'].tolist()):
    test_replies_ids.append(all_replies_ids.index(reply_id))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 82284/82284 [06:09<00:00, 222.82it/s]

# %%
print(len(test_replies_ids), len(set(test_replies_ids)))
# Out:
# 82284 82284

# %%
np.save('../data/test/replies_indices.npy', np.array(test_replies_ids))

# %% [markdown]
# ## Sort

# %%
post_indices = np.load('../data/test/post_indices.npy')
post_indices = np.sort(post_indices)
print(post_indices.shape)
# Out:
# (15212,)

# %%
test_posts_df = all_posts_df.iloc[post_indices]
test_posts_df
# Out:
#                                  id  summarized  \
# 2                            r2w43k           0
# 16                           r2qqyz           0
# 28                           r2doqc           0
# 30                           r2cedp           1
# 42                           r1zcsu           1
# ...                             ...         ...
# 152675  hit:12318_conv:24637_uttr:1           0
# 152676  hit:12384_conv:24768_uttr:1           0
# 152677  hit:12390_conv:24781_uttr:1           0
# 152678  hit:12398_conv:24797_uttr:1           1
# 152679  hit:12416_conv:24832_uttr:1           0
#
#                                                      text    root  length
# 2       Do you ever feel like everyone else has it tog...    feel      13
# 16      I've finally figured out the answer to the que...  figure      21
# 28      I cooked the entree for my Friendsgiving for t...    cook      14
# 30      At my job where I work with kids 5-13, I start...   start      23
# 42                          Having enough food and water.    have       6
# ...                                                   ...     ...     ...
# 152675  I don't like scammy sales people, nothing good...    come      13
# 152676    I almost got caught stealing, I felt pretty bad    feel      10
# 152677  Some random dude walked into my room while I w...    walk      19
# 152678       I saw my favourite candy at the store today!     see      10
# 152679     I saw a huge cockroach outside my house today!     see      10
#
# [15212 rows x 5 columns]

# %%
np.save('../data/test/posts_indices.npy', post_indices)
test_posts_df.to_csv('../data/test/posts.csv', index = False)

# %% [markdown]
# -----

# %%
reply_indices = np.load('../data/test/reply_indices.npy')
reply_indices = np.sort(reply_indices)
print(reply_indices.shape)
# Out:
# (82284,)

# %%
test_replies_df = all_replies_df.iloc[reply_indices]
test_replies_df
# Out:
#                                  id                    parent_id  summarized  \
# 16                          hm61y7k                       r2qqyz           0
# 17                          hm63dh1                       r2qqyz           1
# 61                          hm70wwb                       r2w43k           1
# 68                          hm7608z                       r2w43k           1
# 120                         hm49qhc                       r2doqc           1
# ...                             ...                          ...         ...
# 838780  hit:12318_conv:24637_uttr:2  hit:12318_conv:24637_uttr:1           0
# 838781  hit:12384_conv:24768_uttr:2  hit:12384_conv:24768_uttr:1           1
# 838782  hit:12390_conv:24781_uttr:2  hit:12390_conv:24781_uttr:1           1
# 838783  hit:12398_conv:24797_uttr:2  hit:12398_conv:24797_uttr:1           1
# 838784  hit:12416_conv:24832_uttr:2  hit:12416_conv:24832_uttr:1           0
#
#                                                      text  length
# 16             Man, I wouldn't know where to get started.      11
# 17      Having said that, The Nice Guys would always b...      14
# 61                               I hope this kinda helps.       6
# 68      One of the gifts of middle age is that I have ...      18
# 120                                 Happy Thanksgiving :)       3
# ...                                                   ...     ...
# 838780         I agree, were you recently screwed by one?      10
# 838781                                              Ouch!       2
# 838782                              Oh wow that is weird.       6
# 838783                                           Oh nice.       3
# 838784                     did you call the exterminator?       6
#
# [82284 rows x 5 columns]

# %%
np.save('../data/test/replies_indices.npy', reply_indices)
test_replies_df.to_csv('../data/test/replies.csv', index = False)

# %% [markdown]
# # Generate Test CSV with 41 Labels

# %%
all_posts_df = pd.read_csv('../data/merged_q/all_posts_max_len_40_labeled.csv')
all_replies_df = pd.read_csv('../data/merged_q/all_replies_max_len_40_labeled.csv')
print('all_posts_df shape = {}'.format(all_posts_df.shape))
print('all_replies_df shape = {}'.format(all_replies_df.shape))
# Out:
# all_posts_df shape = (152680, 6)
# all_replies_df shape = (838785, 6)

# %%
post_indices = np.load('../data/test/posts_indices.npy')
print(post_indices.shape)
# Out:
# (15212,)

# %%
test_posts_df = all_posts_df.iloc[post_indices]
test_posts_df
# Out:
#                                  id  summarized  \
# 2                            r2w43k           0
# 16                           r2qqyz           0
# 28                           r2doqc           0
# 30                           r2cedp           1
# 42                           r1zcsu           1
# ...                             ...         ...
# 152675  hit:12318_conv:24637_uttr:1           0
# 152676  hit:12384_conv:24768_uttr:1           0
# 152677  hit:12390_conv:24781_uttr:1           0
# 152678  hit:12398_conv:24797_uttr:1           1
# 152679  hit:12416_conv:24832_uttr:1           0
#
#                                                      text    root  length  \
# 2       Do you ever feel like everyone else has it tog...    feel      13
# 16      I've finally figured out the answer to the que...  figure      21
# 28      I cooked the entree for my Friendsgiving for t...    cook      14
# 30      At my job where I work with kids 5-13, I start...   start      23
# 42                          Having enough food and water.    have       6
# ...                                                   ...     ...     ...
# 152675  I don't like scammy sales people, nothing good...    come      13
# 152676    I almost got caught stealing, I felt pretty bad    feel      10
# 152677  Some random dude walked into my room while I w...    walk      19
# 152678       I saw my favourite candy at the store today!     see      10
# 152679     I saw a huge cockroach outside my house today!     see      10
#
#             emotion
# 2       questioning
# 16      questioning
# 28            proud
# 30         prepared
# 42         prepared
# ...             ...
# 152675     trusting
# 152676       guilty
# 152677    surprised
# 152678      excited
# 152679    terrified
#
# [15212 rows x 6 columns]

# %%
test_posts_df.to_csv('../data/test/posts_labeled_41.csv', index = False)

# %% [markdown]
# ---

# %%
reply_indices = np.load('../data/test/replies_indices.npy')
print(reply_indices.shape)
# Out:
# (82284,)

# %%
test_replies_df = all_replies_df.iloc[reply_indices]
test_replies_df
# Out:
#                                  id                    parent_id  summarized  \
# 16                          hm61y7k                       r2qqyz           0
# 17                          hm63dh1                       r2qqyz           1
# 61                          hm70wwb                       r2w43k           1
# 68                          hm7608z                       r2w43k           1
# 120                         hm49qhc                       r2doqc           1
# ...                             ...                          ...         ...
# 838780  hit:12318_conv:24637_uttr:2  hit:12318_conv:24637_uttr:1           0
# 838781  hit:12384_conv:24768_uttr:2  hit:12384_conv:24768_uttr:1           1
# 838782  hit:12390_conv:24781_uttr:2  hit:12390_conv:24781_uttr:1           1
# 838783  hit:12398_conv:24797_uttr:2  hit:12398_conv:24797_uttr:1           1
# 838784  hit:12416_conv:24832_uttr:2  hit:12416_conv:24832_uttr:1           0
#
#                                                      text  length  \
# 16             Man, I wouldn't know where to get started.      11
# 17      Having said that, The Nice Guys would always b...      14
# 61                               I hope this kinda helps.       6
# 68      One of the gifts of middle age is that I have ...      18
# 120                                 Happy Thanksgiving :)       3
# ...                                                   ...     ...
# 838780         I agree, were you recently screwed by one?      10
# 838781                                              Ouch!       2
# 838782                              Oh wow that is weird.       6
# 838783                                           Oh nice.       3
# 838784                     did you call the exterminator?       6
#
#               emotion
# 16      acknowledging
# 17           agreeing
# 61        encouraging
# 68            jealous
# 120           wishing
# ...               ...
# 838780    questioning
# 838781      disgusted
# 838782      surprised
# 838783  acknowledging
# 838784    questioning
#
# [82284 rows x 6 columns]

# %%
test_replies_df.to_csv('../data/test/replies_labeled_41.csv', index = False)
